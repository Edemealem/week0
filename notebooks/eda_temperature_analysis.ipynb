# %% [markdown]
# Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **I am conducting separate analyses for both datasets provided to me.**

# %% [markdown]
# **Load data**
#
# 1.   benin-malanville

# %%
benin_df = pd.read_csv("/content/drive/MyDrive/10Academy/benin-malanville.csv")
benin_df.head(3)
# Out:
#           Timestamp  GHI  DNI  DHI  ModA  ModB  Tamb    RH   WS  WSgust  \
# 0  2021-08-09 00:01 -1.2 -0.2 -1.1   0.0   0.0  26.2  93.4  0.0     0.4
# 1  2021-08-09 00:02 -1.1 -0.2 -1.1   0.0   0.0  26.2  93.6  0.0     0.0
# 2  2021-08-09 00:03 -1.1 -0.2 -1.1   0.0   0.0  26.2  93.7  0.3     1.1
#
#    WSstdev     WD  WDstdev   BP  Cleaning  Precipitation  TModA  TModB  \
# 0      0.1  122.1      0.0  998         0            0.0   26.3   26.2
# 1      0.0    0.0      0.0  998         0            0.0   26.3   26.2
# 2      0.5  124.6      1.5  997         0            0.0   26.4   26.2
#
#    Comments
# 0       NaN
# 1       NaN
# 2       NaN

# %% [markdown]
# **Temperature Analysis**

# %%
benin_df[['Tamb', 'RH', 'GHI', 'DNI', 'DHI']].describe()
# Out:
#                 Tamb             RH            GHI            DNI  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean       28.179683      54.487969     240.559452     167.187516
# std         5.924297      28.073069     331.131327     261.710501
# min        11.000000       2.100000     -12.900000      -7.800000
# 25%        24.200000      28.800000      -2.000000      -0.500000
# 50%        28.000000      55.100000       1.800000      -0.100000
# 75%        32.300000      80.100000     483.400000     314.200000
# max        43.800000     100.000000    1413.000000     952.300000
#
#                  DHI
# count  525600.000000
# mean      115.358961
# std       158.691074
# min       -12.600000
# 25%        -2.100000
# 50%         1.600000
# 75%       216.300000
# max       759.200000

# %% [markdown]
# letsplot ScatterPlot **"RH" and "Tamb"**

# %%
# RH vs. Temperatures
plt.subplot(1, 3, 1)
sns.scatterplot(x='RH', y='Tamb', data=benin_df)
plt.title('RH vs Tamb')
plt.xlabel('Relative Humidity (%)')
plt.ylabel('Temperature (°C)')

plt.subplot(1, 3, 2)
sns.scatterplot(x='RH', y='GHI', data=benin_df)
plt.title('RH vs GHI')
plt.xlabel('Relative Humidity (%)')
plt.ylabel('GHI')

plt.subplot(1, 3, 3)
sns.scatterplot(x='RH', y='DNI', data=benin_df)
plt.title('RH vs DNI')
plt.xlabel('Relative Humidity (%)')
plt.ylabel('DNI')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Load data**
#
# 2.   sierraleone dataset

# %%
sierraleone_df = pd.read_csv("/content/drive/MyDrive/10Academy/sierraleone-bumbuna.csv")
sierraleone_df.head(3)
# Out:
#           Timestamp  GHI  DNI  DHI  ModA  ModB  Tamb    RH   WS  WSgust  \
# 0  2021-10-30 00:01 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.1  0.0     0.0
# 1  2021-10-30 00:02 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 2  2021-10-30 00:03 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
#
#    WSstdev   WD  WDstdev    BP  Cleaning  Precipitation  TModA  TModB  \
# 0      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 1      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 2      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
#
#    Comments
# 0       NaN
# 1       NaN
# 2       NaN

# %% [markdown]
# **Temprature Analysis**

# %%
sierraleone_df[['Tamb', 'RH', 'GHI', 'DNI', 'DHI']].describe()
# Out:
#                 Tamb             RH            GHI            DNI  \
# count  499081.000000  499081.000000  499081.000000  499081.000000
# mean       26.064254      80.460931     167.993678      91.355282
# std         4.316197      20.035806     256.577968     186.271956
# min        12.300000       9.900000     -15.900000      -7.800000
# 25%        23.100000      70.200000      -3.700000      -0.300000
# 50%        25.000000      86.700000      -0.500000      -0.100000
# 75%        28.900000      97.100000     303.000000      44.300000
# max        39.900000     100.000000    1025.000000     891.000000
#
#                  DHI
# count  499081.000000
# mean      103.746489
# std       153.207807
# min       -16.700000
# 25%        -4.300000
# 50%        -0.800000
# 75%       204.400000
# max       827.000000

# %%
# RH vs. Temperatures
plt.subplot(1, 3, 1)
sns.scatterplot(x='RH', y='Tamb', data=sierraleone_df)
plt.title('RH vs Tamb')
plt.xlabel('Relative Humidity (%)')
plt.ylabel('Temperature (°C)')

plt.subplot(1, 3, 2)
sns.scatterplot(x='RH', y='GHI', data=sierraleone_df)
plt.title('RH vs GHI')
plt.xlabel('Relative Humidity (%)')
plt.ylabel('GHI')

plt.subplot(1, 3, 3)
sns.scatterplot(x='RH', y='DNI', data=sierraleone_df)
plt.title('RH vs DNI')
plt.xlabel('Relative Humidity (%)')
plt.ylabel('DNI')

plt.tight_layout()
plt.show()

# %% [markdown]
# Data load
# 3. Togo

# %%
togo_df = pd.read_csv("/content/drive/MyDrive/10Academy/togo-dapaong_qc.csv")
togo_df.head(3)
# Out:
#           Timestamp  GHI  DNI  DHI  ModA  ModB  Tamb    RH   WS  WSgust  \
# 0  2021-10-25 00:01 -1.3  0.0  0.0   0.0   0.0  24.8  94.5  0.9     1.1
# 1  2021-10-25 00:02 -1.3  0.0  0.0   0.0   0.0  24.8  94.4  1.1     1.6
# 2  2021-10-25 00:03 -1.3  0.0  0.0   0.0   0.0  24.8  94.4  1.2     1.4
#
#    WSstdev     WD  WDstdev   BP  Cleaning  Precipitation  TModA  TModB  \
# 0      0.4  227.6      1.1  977         0            0.0   24.7   24.4
# 1      0.4  229.3      0.7  977         0            0.0   24.7   24.4
# 2      0.3  228.5      2.9  977         0            0.0   24.7   24.4
#
#    Comments
# 0       NaN
# 1       NaN
# 2       NaN

# %% [markdown]
# **Temprature Analysis**

# %%
togo_df[['Tamb', 'RH', 'GHI', 'DNI', 'DHI']].describe()
# Out:
#                 Tamb             RH            GHI            DNI  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean       27.751788      55.013160     230.555040     151.258469
# std         4.758023      28.778732     322.532347     250.956962
# min        14.900000       3.300000     -12.700000       0.000000
# 25%        24.200000      26.500000      -2.200000       0.000000
# 50%        27.200000      59.300000       2.100000       0.000000
# 75%        31.100000      80.800000     442.400000     246.400000
# max        41.400000      99.800000    1424.000000    1004.500000
#
#                  DHI
# count  525600.000000
# mean      116.444352
# std       156.520714
# min         0.000000
# 25%         0.000000
# 50%         2.500000
# 75%       215.700000
# max       805.700000

# %%
# RH vs. Temperatures
plt.subplot(1, 3, 1)
sns.scatterplot(x='RH', y='Tamb', data=togo_df)
plt.title('RH vs Tamb')
plt.xlabel('Relative Humidity (%)')
plt.ylabel('Temperature (°C)')

plt.subplot(1, 3, 2)
sns.scatterplot(x='RH', y='GHI', data=togo_df)
plt.title('RH vs GHI')
plt.xlabel('Relative Humidity (%)')
plt.ylabel('GHI')

plt.subplot(1, 3, 3)
sns.scatterplot(x='RH', y='DNI', data=togo_df)
plt.title('RH vs DNI')
plt.xlabel('Relative Humidity (%)')
plt.ylabel('DNI')

plt.tight_layout()
plt.show()
